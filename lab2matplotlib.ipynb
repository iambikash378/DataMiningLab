# %% [markdown]
# <a href="https://colab.research.google.com/github/iambikash378/DataMiningLab/blob/main/lab2matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
data = np.random.randint(0,100, 100 )
plt.hist(data)
plt.show()

# %%
#Visualizing Box-Plots

import seaborn as sb
import pandas as pd

# %%
df = pd.DataFrame({
    'Salary' : np.random.randint(10000, 100000, 50)
})

# %%
sb.boxplot(data = df, x = 'Salary')
# Out:
# <Axes: xlabel='Salary'>
